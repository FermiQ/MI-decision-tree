# %%
import matplotlib.pyplot as plt

# %%
elements = ["Cu", "Fe", "Ni",'FeNi','NiCo','NiCoCr','FeNiCr','FeNiCo','CrCoFeNi']
MD_simulated_values = [1160,2733,2215,2463,2170,2116,2275,2357,2270] # Values from the MD

# From the SIMTOOL Workflow:
#Experimental melting temperatures [K]
T_m_Cr = 2180
T_m_Co = 1768
T_m_Cu = 1358
T_m_Fe = 1811
T_m_Ni = 1728

experimental_values = [1358, 1811, 1728, (1430+273),(1462+273),(1417+273),(1391+273),(1451+273),(1422+273)] # Values from the Exp

# %%
fig = plt.figure(figsize = (12,10))

plt.plot([1000,2800], [1000,2800],'k--')
plt.plot(experimental_values, MD_simulated_values, 'o', markersize=12, color='black')
plt.xticks(fontsize=26)
plt.yticks(fontsize=26)
plt.xlim([1100,2800])
plt.ylim([1100,2800])
plt.grid()
plt.ylabel('MD-Simulated Values (K)', fontsize=26)
plt.xlabel('Experimental Values (K)', fontsize=26)

for x,y,elm in zip(experimental_values[:2],MD_simulated_values[:2], elements[:2]):

    label = "{}".format(elm)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,7), # distance from text to points (x,y)
                 size=20,
                 ha='center') # horizontal alignment can be left, right or center
    
#for x,y,elm in zip(experimental_values[5:8],MD_simulated_values[5:8], elements[5:8]):
#
#    label = "{}".format(elm)
#
#    plt.annotate(label, # this is the text
#                 (x,y), # this is the point to label
#                 textcoords="offset points", # how to position the text
#                 xytext=(0,7), # distance from text to points (x,y)
#                 size=20,
#                 ha='center') # horizontal alignment can be left, right or center

place = 3
label = "{}".format(elements[place])
plt.annotate(label, # this is the text
                 (experimental_values[place],MD_simulated_values[place]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,7), # distance from text to points (x,y)
                 size=22,
                ha='center') # horizontal alignment can be left, right or center
place = 7
label = "{}".format(elements[place])
plt.annotate(label, # this is the text
                 (experimental_values[place],MD_simulated_values[place]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,7), # distance from text to points (x,y)
                 size=22,
                ha='center') # horizontal alignment can be left, right or center


label = "{}".format(elements[8])
plt.annotate(label, # this is the text
                 (experimental_values[8],MD_simulated_values[8]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(120,10), # distance from text to points (x,y)
                 size=22,
                 arrowprops=dict(arrowstyle="->",facecolor='black',connectionstyle="arc3,rad=0.15",shrinkA=5, shrinkB=5),
                 ha='center') # horizontal alignment can be left, right or center

label = "{}".format(elements[4])
plt.annotate(label, # this is the text
                 (experimental_values[4],MD_simulated_values[4]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(60,10), # distance from text to points (x,y)
                 size=22,
                 arrowprops=dict(arrowstyle="->",facecolor='black',connectionstyle="arc3,rad=0.15",shrinkA=5, shrinkB=5),
                 ha='center') # horizontal alignment can be left, right or center

label = "{}".format(elements[5])
plt.annotate(label, # this is the text
                 (experimental_values[5],MD_simulated_values[5]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(70,-10), # distance from text to points (x,y)
                 size=22,
                 arrowprops=dict(arrowstyle="->",facecolor='black',connectionstyle="arc3,rad=0.15",shrinkA=5, shrinkB=5),
                 ha='center') # horizontal alignment can be left, right or center

label = "{}".format(elements[6])
plt.annotate(label, # this is the text
                 (experimental_values[6],MD_simulated_values[6]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(-70,-10), # distance from text to points (x,y)
                 size=22,
                 arrowprops=dict(arrowstyle="->",facecolor='black',connectionstyle="arc3,rad=0.15",shrinkA=5, shrinkB=5),
                 ha='center') # horizontal alignment can be left, right or center

label = "{}".format(elements[2])
plt.annotate(label, # this is the text
                 (experimental_values[2],MD_simulated_values[2]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(-70,-10), # distance from text to points (x,y)
                 size=22,
                 arrowprops=dict(arrowstyle="->",facecolor='black',connectionstyle="arc3,rad=0.15",shrinkA=5, shrinkB=5),
                 ha='center') # horizontal alignment can be left, right or center


fig.show()

#3,7
